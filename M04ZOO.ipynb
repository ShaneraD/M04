# %%
11.1
Create a file named zoo.py that contains a function called hours() which prints the string "open 9-5 daily"
Then, use the interactive interpreter to import the zoo module and call its hours() function.

# %%
import zoo
zoo.hours()
# Out:
# Open 9-5 daily

# %%
11.2
Import the zoo module using an alias called menagerie, and call the hours() function using the alias.

# %%
import zoo as menagerie

menagerie.hours()
# Out:
# Open 9-5 daily
